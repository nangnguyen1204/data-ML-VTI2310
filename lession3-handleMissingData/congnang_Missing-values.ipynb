# %% [markdown]
# None: Missing Value Pythonic
# là đối tượng trong Python nên chỉ sử dụng trong mảng có kiểu dữ liệu 'object'

# %%
import numpy as np
import pandas as pd

# %%
vals1 = np.array([1, None, 3, 4])
vals1
# Out:
# array([1, None, 3, 4], dtype=object)

# %%
for dtype in ['object', 'int']:
    print("dtype =", dtype)
    # %timeit np.arange(1E6, dtype=dtype).sum()
    print()
# Out:
# dtype = object
# 89 ms ± 22.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# dtype = int
# 1.02 ms ± 35.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
vals1.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-30a3fc8c6726> in <cell line: 1>()
# ----> 1 vals1.sum()
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# phép cộng giữa none và 1 số nguyên không được xác định

# %% [markdown]
# NaN : Thiếu dữ liệu số (Not a Number)

# %%
vals2 = np.array([1, np.nan, 3, 4])
vals2.dtype
# Out:
# dtype('float64')

# %%
1 + np.nan
# Out:
# nan

# %%
0 *  np.nan
# Out:
# nan

# %%
vals2.sum(), vals2.min(), vals2.max()
# Out:
# (nan, nan, nan)

# %% [markdown]
# hàm bỏ qua giá trị NaN: nansum, nanmin,nanmax

# %%
np.nansum(vals2), np.nanmin(vals2), np.nanmax(vals2)
# Out:
# (8.0, 1.0, 4.0)

# %% [markdown]
# NaN và None trong Pandas

# %%
pd.Series([1, np.nan, 2, None])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %%
x = pd.Series(range(2), dtype=int)
x
# Out:
# 0    0
# 1    1
# dtype: int64

# %%
x[0] = None
x
# Out:
# 0    NaN
# 1    1.0
# dtype: float64

# %% [markdown]
# tự chuyển None thành NaN

# %% [markdown]
# Null

# %%
data = pd.Series([1, np.nan, 'hello', None])

# %%
data.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data[data.notnull()]
# Out:
# 0        1
# 2    hello
# dtype: object

# %% [markdown]
# Bỏ giá trị Null

# %% [markdown]
# dropna() : loại bỏ tất cả hàng có giá trị null

# %%
data.dropna()
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
df = pd.DataFrame([[1,      np.nan, 2],
                   [2,      3,      5],
                   [np.nan, 4,      6]])
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.dropna()
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %%
df.dropna(axis='columns')
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %%
df[3] = np.nan
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %% [markdown]
# how = 'all': chỉ xóa hàng hàng hoặc cột có tất cả là null
# how = 'any' : xóa bất kì hàng hoặc cột nào có giá trị null

# %%
df.dropna(axis='columns', how='all')
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %% [markdown]
# thresh: chỉ định số lượng giá trị khác null tối thiểu cho cột/hàng được giữ lại

# %%
df.dropna(axis='rows', thresh=3)
# Out:
#      0    1  2   3
# 1  2.0  3.0  5 NaN

# %% [markdown]
# Điền giá trị vào null

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
data.fillna(0)
# Out:
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64

# %% [markdown]
# điền chuyển tiếp giá trị trước đó

# %%
data.fillna(method='ffill')
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %% [markdown]
# truyền ngược giá trị sau lên

# %%
data.fillna(method='bfill')
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %%
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
df.fillna(method='ffill', axis=1)
# Out:
#      0    1    2    3
# 0  1.0  1.0  2.0  2.0
# 1  2.0  3.0  5.0  5.0
# 2  NaN  4.0  6.0  6.0

# %%
 df = pd.DataFrame({'A': [1, 2, None, 4, None],
                      'B': [None, 6, 7, None, 9]})

   # Kiểm tra thông tin DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       3 non-null      float64
# dtypes: float64(2)
# memory usage: 208.0 bytes

# %%
 df = pd.DataFrame({'A': [1, 2, None, 4, None],
                      'B': [None, 6, 7, None, 9]})

   # Đếm số lượng dữ liệu không thiếu cho từng cột

# %%
   df.count()
# Out:
# A    3
# B    3
# dtype: int64
